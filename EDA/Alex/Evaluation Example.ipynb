# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt

# %%
item_orders_dec = pd.read_csv("../../Data/train_before_dec.csv")
item_orders_dec["date"] = pd.to_datetime(item_orders_dec["date"])
item_orders_dec
# Out:
#              date  userID  itemID  order  brand  feature_1  feature_2  \
# 0      2020-06-01   38769    3477      1    186          6          0
# 1      2020-06-01   42535   30474      1    193         10          3
# 2      2020-06-01   42535   15833      1   1318          4          1
# 3      2020-06-01   42535   20131      1    347          4          0
# 4      2020-06-01   42535    4325      1    539          6          0
# ...           ...     ...     ...    ...    ...        ...        ...
# 767126 2020-11-30   22541     746      1    406         10          0
# 767127 2020-11-30   36315   22834     20    993         10          3
# 767128 2020-11-30    7736   18630      3      6          4          0
# 767129 2020-11-30    7736   29657      8     18         10          0
# 767130 2020-11-30   10215   29037      1   1180          4          0
#
#         feature_3  feature_4  feature_5  \
# 0             196          0         45
# 1             229          3        132
# ...

# %%
item_orders_jan = pd.read_csv("../../Data/train_before_jan.csv")
item_orders_jan["date"] = pd.to_datetime(item_orders_jan["date"])
item_orders_jan
# Out:
#              date  userID  itemID  order  brand  feature_1  feature_2  \
# 0      2020-06-01   38769    3477      1    186          6          0
# 1      2020-06-01   42535   30474      1    193         10          3
# 2      2020-06-01   42535   15833      1   1318          4          1
# 3      2020-06-01   42535   20131      1    347          4          0
# 4      2020-06-01   42535    4325      1    539          6          0
# ...           ...     ...     ...    ...    ...        ...        ...
# 905876 2020-12-31   38399   32075      1   1111          4          0
# 905877 2020-12-31   38399   23050      1   1411          4          0
# 905878 2020-12-31   21613   25422      1    539         10          0
# 905879 2020-12-31   27030      52      1    799         10          1
# 905880 2020-12-31   27030   31073      1   1126          4          0
#
#         feature_3  feature_4  feature_5  \
# 0             196          0         45
# 1             229          3        132
# ...

# %%
NOW = dt(2020, 12, 1)

features_dec = item_orders_dec.groupby("userID").agg({
    "date": lambda x: (NOW - x.max()).days,
    "itemID": "size",
    "order": ["mean", "sum"],
    }).reset_index()

features_dec.columns = ["userID", "recency", "frequency", "quantity_avg", "quantity_total"]
features_dec.tail()
# Out:
#        userID  recency  frequency  quantity_avg  quantity_total
# 45760   46133        9         21      1.095238              23
# 45761   46134       17         26      1.230769              32
# 45762   46135       18          6      1.666667              10
# 45763   46136       33         32      1.812500              58
# 45764   46137       75          5      1.400000               7

# %%
NOW = dt(2021, 1, 1)

features_jan = item_orders_jan.groupby("userID").agg({
    "date": lambda x: (NOW - x.max()).days,
    "itemID": "size",
    "order": ["mean", "sum"],
    }).reset_index()

features_jan.columns = ["userID", "recency", "frequency", "quantity_avg", "quantity_total"]
features_jan.tail()
# Out:
#        userID  recency  frequency  quantity_avg  quantity_total
# 46026   46133       40         21      1.095238              23
# 46027   46134       19         27      1.222222              33
# 46028   46135       25          7      1.857143              13
# 46029   46136        4         35      1.971429              69
# 46030   46137      106          5      1.400000               7

# %%
user_item_data_dec = pd.merge(item_orders_dec, features_dec, on=["userID"], how="left").drop(["date", "categories"], axis=1)
user_item_data_dec.head()
# Out:
#    userID  itemID  order  brand  feature_1  feature_2  feature_3  feature_4  \
# 0   38769    3477      1    186          6          0        196          0
# 1   42535   30474      1    193         10          3        229          3
# 2   42535   15833      1   1318          4          1        455          0
# 3   42535   20131      1    347          4          0        291          3
# 4   42535    4325      1    539          6          0        303          0
#
#    feature_5  purchaseWeek  recency
# 0         45             1        1
# 1        132             1       71
# 2        108             1       71
# 3         44             1       71
# 4         45             1       71

# %%
user_item_data_jan = pd.merge(item_orders_jan, features_jan, on=["userID"], how="left").drop(["date", "categories"], axis=1)
user_item_data_jan.head()
# Out:
#    userID  itemID  order  brand  feature_1  feature_2  feature_3  feature_4  \
# 0   38769    3477      1    186          6          0        196          0
# 1   42535   30474      1    193         10          3        229          3
# 2   42535   15833      1   1318          4          1        455          0
# 3   42535   20131      1    347          4          0        291          3
# 4   42535    4325      1    539          6          0        303          0
#
#    feature_5  purchaseWeek  recency
# 0         45             1       26
# 1        132             1        9
# 2        108             1        9
# 3         44             1        9
# 4         45             1        9

# %%
submission_dec = pd.read_csv("../../Data/test_dec.csv", sep="|")

submission_dec = pd.merge(submission_dec, user_item_data_dec.drop(["purchaseWeek"], axis=1), on=["userID", "itemID"], how="left")
submission_dec = submission_dec.drop_duplicates(["userID", "itemID"])
submission_dec
# Out:
#        userID  itemID  prediction  order  brand  feature_1  feature_2  \
# 0           0   20664           2      1    408          4          0
# 2           0   28231           2      1    193          4          3
# 3          13    2690           4      1    406          4          3
# 6          15    1299           4      1   1056          4          0
# 8          15   20968           4      1   1315          4          0
# ...       ...     ...         ...    ...    ...        ...        ...
# 23512   46118   20106           4      1   1111          4          0
# 23516   46124   19677           4      1   1006          4          0
# 23520   46125   12878           0      1   1111          4          0
# 23522   46127    7963           2      2   1111          4          0
# 23526   46130     395           3      1    745          4          0
#
#        feature_3  feature_4  feature_5  recency
# 0            284          0         66       11
# ...

# %%
submission_jan = pd.read_csv("../../Data/test_jan.csv", sep="|")

submission_jan = pd.merge(submission_jan, user_item_data_jan.drop(["purchaseWeek"], axis=1), on=["userID", "itemID"], how="left")
submission_jan = submission_jan.drop_duplicates(["userID", "itemID"])
submission_jan
# Out:
#        userID  itemID  prediction  order  brand  feature_1  feature_2  \
# 0           0   20664           0      1    408          4          0
# 3           0   28231           4      1    193          4          3
# 5          13    2690           0      1    406          4          3
# 9          15    1299           2      1   1056          4          0
# 12         15   20968           4      1   1315          4          0
# ...       ...     ...         ...    ...    ...        ...        ...
# 27715   46118   20106           0      1   1111          4          0
# 27720   46124   19677           4      1   1006          4          0
# 27725   46125   12878           4      1   1111          4          0
# 27727   46127    7963           0      2   1111          4          0
# 27732   46130     395           0      1    745          4          0
#
#        feature_3  feature_4  feature_5  recency
# 0            284          0         66       21
# ...

# %%
user_item_target_dec = user_item_data_dec["purchaseWeek"]
user_item_body_dec = user_item_data_dec.drop(columns="purchaseWeek")

submission_target_dec = submission_dec["prediction"]
submission_body_dec = submission_dec.drop(columns="prediction")

# %%
user_item_target_jan = user_item_data_jan["purchaseWeek"]
user_item_body_jan = user_item_data_jan.drop(columns="purchaseWeek")

submission_target_jan = submission_dec["prediction"]
submission_body_jan = submission_dec.drop(columns="prediction")

# %%
# Temporal change of working directory to import function
import os
os.chdir("../../Helper_Functions")
from evaluation_pipeline import evaluate_models, calculate_feature_gain
# Needs to be current working directory
os.chdir("../EDA/Alex")

# %%
df, pred_dec, pred_jan = calculate_feature_gain(user_item_body_dec, user_item_target_dec, user_item_body_jan, user_item_target_jan, features=["recency"], path_to_data="../../Data")

# %%
df
# Out:
#                         w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression              0.285429           0.329941  0.044512
# GaussianNB                      0.293704           0.311299  0.017596
# KNeighborsClassifier            0.316530           0.317386  0.000856
# DecisionTreeClassifier          0.317767           0.318005  0.000238
#
#                         w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression              0.303765           0.317867  0.014102
# GaussianNB                      0.300088           0.306371  0.006283
# KNeighborsClassifier            0.313445           0.313026 -0.000419
# DecisionTreeClassifier          0.314516           0.314237 -0.000279
#
#                         overall score w/o features  \
# model_name
# LogisticRegression                        0.294597
# GaussianNB                                0.296896
# KNeighborsClassifier                      0.314988
# ...

# %%
pred_dec
# Out:
#       userID  itemID  prediction
# 0          0   20664           1
# 1          0   28231           3
# 2         13    2690           0
# 3         15    1299           0
# 4         15   20968           0
# ...      ...     ...         ...
# 9740   46118   20106           1
# 9741   46124   19677           2
# 9742   46125   12878           1
# 9743   46127    7963           0
# 9744   46130     395           1
#
# [9745 rows x 3 columns]

# %%
pred_jan
# Out:
#       userID  itemID  prediction
# 0          0   20664           2
# 1          0   28231           2
# 2         13    2690           4
# 3         15    1299           0
# 4         15   20968           0
# ...      ...     ...         ...
# 9935   46118   20106           1
# 9936   46124   19677           2
# 9937   46125   12878           1
# 9938   46127    7963           0
# 9939   46130     395           1
#
# [9940 rows x 3 columns]

# %%
# df, labels = evaluate_models(user_item_body, user_item_target, submission_body, submission_target)
