# %%
import pandas as pd
import os

# %%
os.chdir("../Helper_Functions")
from evaluation_pipeline import calculate_feature_gain
# Needs to be current working directory
os.chdir("../Main")

# %%
item_orders_dec = pd.read_csv("../Data/train_before_dec.csv")
item_orders_dec["date"] = pd.to_datetime(item_orders_dec["date"])
item_orders_dec
# Out:
#              date  userID  itemID  order  brand  feature_1  feature_2  \
# 0      2020-06-01   38769    3477      1    186          6          0
# 1      2020-06-01   42535   30474      1    193         10          3
# 2      2020-06-01   42535   15833      1   1318          4          1
# 3      2020-06-01   42535   20131      1    347          4          0
# 4      2020-06-01   42535    4325      1    539          6          0
# ...           ...     ...     ...    ...    ...        ...        ...
# 767126 2020-11-30   22541     746      1    406         10          0
# 767127 2020-11-30   36315   22834     20    993         10          3
# 767128 2020-11-30    7736   18630      3      6          4          0
# 767129 2020-11-30    7736   29657      8     18         10          0
# 767130 2020-11-30   10215   29037      1   1180          4          0
#
#         feature_3  feature_4  feature_5  \
# 0             196          0         45
# 1             229          3        132
# ...

# %%
item_orders_jan = pd.read_csv("../Data/train_before_jan.csv")
item_orders_jan["date"] = pd.to_datetime(item_orders_jan["date"])
item_orders_jan
# Out:
#              date  userID  itemID  order  brand  feature_1  feature_2  \
# 0      2020-06-01   38769    3477      1    186          6          0
# 1      2020-06-01   42535   30474      1    193         10          3
# 2      2020-06-01   42535   15833      1   1318          4          1
# 3      2020-06-01   42535   20131      1    347          4          0
# 4      2020-06-01   42535    4325      1    539          6          0
# ...           ...     ...     ...    ...    ...        ...        ...
# 905876 2020-12-31   38399   32075      1   1111          4          0
# 905877 2020-12-31   38399   23050      1   1411          4          0
# 905878 2020-12-31   21613   25422      1    539         10          0
# 905879 2020-12-31   27030      52      1    799         10          1
# 905880 2020-12-31   27030   31073      1   1126          4          0
#
#         feature_3  feature_4  feature_5  \
# 0             196          0         45
# 1             229          3        132
# ...

# %%
rf_dec = pd.read_csv("../Data/Feature CSVs/rfm_analysis_dec.csv")
rf_dec
# Out:
#        userID  recency  frequency  quantity_avg  quantity_total  R  F  \
# 0           0       11          9      1.000000               9  3  2
# 1           1        2         10      1.300000              13  4  2
# 2           2        3         18      1.166667              21  4  3
# 3           3       10         31      1.290323              40  3  4
# 4           4        2         17      1.705882              29  4  3
# ...       ...      ...        ...           ...             ... .. ..
# 45760   46133        9         21      1.095238              23  3  3
# 45761   46134       17         26      1.230769              32  3  4
# 45762   46135       18          6      1.666667              10  3  1
# 45763   46136       33         32      1.812500              58  2  4
# 45764   46137       75          5      1.400000               7  1  1
#
#        RF_Segment_Concat  RF_Score  RF_Level
# 0                     32         5         2
# ...

# %%
rf_jan = pd.read_csv("../Data/Feature CSVs/rfm_analysis_jan.csv")
rf_jan
# Out:
#        userID  recency  frequency  quantity_avg  quantity_total  R  F  \
# 0           0       21         14      1.000000              14  3  2
# 1           1       23         12      1.250000              15  2  2
# 2           2       13         20      1.200000              24  3  3
# 3           3        3         38      1.289474              49  4  4
# 4           4       33         17      1.705882              29  2  2
# ...       ...      ...        ...           ...             ... .. ..
# 46026   46133       40         21      1.095238              23  1  3
# 46027   46134       19         27      1.222222              33  3  4
# 46028   46135       25          7      1.857143              13  2  1
# 46029   46136        4         35      1.971429              69  4  4
# 46030   46137      106          5      1.400000               7  1  1
#
#        RF_Segment_Concat  RF_Score  RF_Level
# 0                     32         5         2
# ...

# %%
item_orders_dec_2 = pd.merge(item_orders_dec, rf_dec, on=["userID"], how="left")
item_orders_dec_2
# Out:
#              date  userID  itemID  order  brand  feature_1  feature_2  \
# 0      2020-06-01   38769    3477      1    186          6          0
# 1      2020-06-01   42535   30474      1    193         10          3
# 2      2020-06-01   42535   15833      1   1318          4          1
# 3      2020-06-01   42535   20131      1    347          4          0
# 4      2020-06-01   42535    4325      1    539          6          0
# ...           ...     ...     ...    ...    ...        ...        ...
# 767126 2020-11-30   22541     746      1    406         10          0
# 767127 2020-11-30   36315   22834     20    993         10          3
# 767128 2020-11-30    7736   18630      3      6          4          0
# 767129 2020-11-30    7736   29657      8     18         10          0
# 767130 2020-11-30   10215   29037      1   1180          4          0
#
#         feature_3  feature_4  feature_5  ... purchaseWeek  recency  frequency  \
# ...

# %%
item_orders_jan_2 = pd.merge(item_orders_jan, rf_jan, on=["userID"], how="left")
item_orders_jan_2
# Out:
#              date  userID  itemID  order  brand  feature_1  feature_2  \
# 0      2020-06-01   38769    3477      1    186          6          0
# 1      2020-06-01   42535   30474      1    193         10          3
# 2      2020-06-01   42535   15833      1   1318          4          1
# 3      2020-06-01   42535   20131      1    347          4          0
# 4      2020-06-01   42535    4325      1    539          6          0
# ...           ...     ...     ...    ...    ...        ...        ...
# 905876 2020-12-31   38399   32075      1   1111          4          0
# 905877 2020-12-31   38399   23050      1   1411          4          0
# 905878 2020-12-31   21613   25422      1    539         10          0
# 905879 2020-12-31   27030      52      1    799         10          1
# 905880 2020-12-31   27030   31073      1   1126          4          0
#
#         feature_3  feature_4  feature_5  ... purchaseWeek  recency  frequency  \
# ...

# %%
cols_to_drop = ["date", "categories", "purchaseWeek"] 
X_train_dec, y_train_dec = item_orders_dec_2.drop(cols_to_drop, axis=1), item_orders_dec_2["purchaseWeek"]
X_train_jan, y_train_jan = item_orders_jan_2.drop(cols_to_drop, axis=1), item_orders_jan_2["purchaseWeek"]

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["recency"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.329941  0.044512
# XGBoost Classifier          0.310586           0.323093  0.012507
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.317867  0.014102
# XGBoost Classifier          0.305999           0.317913  0.011914
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.323904
# XGBoost Classifier                    0.308292                     0.320503
#
#                     overall gain
# model_name
# LogisticRegression      0.029307
# XGBoost Classifier      0.012211

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["frequency"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.285334 -0.000095
# XGBoost Classifier          0.310586           0.315674  0.005088
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.302788 -0.000977
# XGBoost Classifier          0.305999           0.306371  0.000372
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.294061
# XGBoost Classifier                    0.308292                     0.311023
#
#                     overall gain
# model_name
# LogisticRegression     -0.000536
# XGBoost Classifier      0.002730

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["quantity_avg"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.285429  0.000000
# XGBoost Classifier          0.310586           0.309302 -0.001284
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.304184  0.000419
# XGBoost Classifier          0.305999           0.310886  0.004887
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.294806
# XGBoost Classifier                    0.308292                     0.310094
#
#                     overall gain
# model_name
# LogisticRegression      0.000209
# XGBoost Classifier      0.001801

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["quantity_total"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.284763 -0.000666
# XGBoost Classifier          0.310586           0.309635 -0.000951
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.302508 -0.001257
# XGBoost Classifier          0.305999           0.305022 -0.000977
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.293636
# XGBoost Classifier                    0.308292                     0.307328
#
#                     overall gain
# model_name
# LogisticRegression     -0.000961
# XGBoost Classifier     -0.000964

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["R"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.285572  0.000143
# XGBoost Classifier          0.310586           0.324234  0.013648
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.304184  0.000419
# XGBoost Classifier          0.305999           0.328710  0.022711
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.294878
# XGBoost Classifier                    0.308292                     0.326472
#
#                     overall gain
# model_name
# LogisticRegression      0.000281
# XGBoost Classifier      0.018180

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["F"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.285429  0.000000
# XGBoost Classifier          0.310586           0.307685 -0.002901
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.303532 -0.000233
# XGBoost Classifier          0.305999           0.306371  0.000372
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.294481
# XGBoost Classifier                    0.308292                     0.307028
#
#                     overall gain
# model_name
# LogisticRegression     -0.000116
# XGBoost Classifier     -0.001264

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["RF_Segment_Concat"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.329893  0.044465
# XGBoost Classifier          0.310586           0.328562  0.017976
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.313864  0.010099
# XGBoost Classifier          0.305999           0.322986  0.016987
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.321879
# XGBoost Classifier                    0.308292                     0.325774
#
#                     overall gain
# model_name
# LogisticRegression      0.027282
# XGBoost Classifier      0.017482

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["RF_Score"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.285286 -0.000143
# XGBoost Classifier          0.310586           0.318908  0.008322
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.303672 -0.000093
# XGBoost Classifier          0.305999           0.311863  0.005864
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.294479
# XGBoost Classifier                    0.308292                     0.315386
#
#                     overall gain
# model_name
# LogisticRegression     -0.000118
# XGBoost Classifier      0.007093

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["RF_Level"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.285572  0.000143
# XGBoost Classifier          0.310586           0.309920 -0.000666
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.303672 -0.000093
# XGBoost Classifier          0.305999           0.315074  0.009075
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.294622
# XGBoost Classifier                    0.308292                     0.312497
#
#                     overall gain
# model_name
# LogisticRegression      0.000025
# XGBoost Classifier      0.004205

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["recency", "RF_Segment_Concat"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.331177  0.045749
# XGBoost Classifier          0.310586           0.320240  0.009654
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.320287  0.016522
# XGBoost Classifier          0.305999           0.320380  0.014381
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.325732
# XGBoost Classifier                    0.308292                     0.320310
#
#                     overall gain
# model_name
# LogisticRegression      0.031135
# XGBoost Classifier      0.012017

# %%
df, _, _ = calculate_feature_gain(X_train_dec, y_train_dec, X_train_jan, y_train_jan, features_to_test=["recency", "frequency"], path_to_data="../Data")
df
# Out:
#                     w/o features dec  with features dec  gain dec  \
# model_name
# LogisticRegression          0.285429           0.333936  0.048507
# XGBoost Classifier          0.310586           0.324662  0.014076
#
#                     w/o features jan  with features jan  gain jan  \
# model_name
# LogisticRegression          0.303765           0.321311  0.017545
# XGBoost Classifier          0.305999           0.317262  0.011263
#
#                     overall score w/o features  overall score with features  \
# model_name
# LogisticRegression                    0.294597                     0.327623
# XGBoost Classifier                    0.308292                     0.320962
#
#                     overall gain
# model_name
# LogisticRegression      0.033026
# XGBoost Classifier      0.012670
